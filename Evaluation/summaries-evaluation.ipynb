# %%
# import os + os.chir is used to get to the llms directory to use the usermodules 
import os
os.chdir('C:/Users/AViey/OneDrive/Documents/College/UCI/Stats/stats170a/copilot/copilot/llms/user_modules') 

import seaborn as sns
import matplotlib.pyplot as plt
from  db import Session, get_training_data, get_model_summary_data
import pandas as pd

session = Session()

# %% [markdown]
# Get data from training & models

# %%
training = get_training_data()
training.head()
# Out:
#    dialogue_id   dataset                                      dialogue_text  \
# 0         3816  training  #Person1#: Good morning, sir. Is there anythin...
# 1            3  training  #Person1#: Excuse me, did you see a set of key...
# 2            4  training  #Person1#: Why didn't you tell me you had a gi...
# 3            5  training  #Person1#: Watsup, ladies! Y'll looking'fine t...
# 4            6  training  #Person1#: Happy birthday, Aims!\n#Person2#: T...
#
#                                       actual_summary actual_sentiment
# 0  #Person2# wants a suit made in 100 % black Bar...          neutral
# 1  #Person1#'s looking for a set of keys and asks...         positive
# 2  #Person1#'s angry because #Person2# didn't tel...         negative
# 3  Malik invites Nikki to dance. Nikki agrees if ...         positive
# 4  Lisa gives Aims a birthday present and Aims lo...         positive

# %%
deci = get_model_summary_data('deciLM 7b')
deci.head()
# Out:
#    summary_id  dialogue_id   model_id  \
# 0       59776        10360  deciLM 7b
# 1       51809         5099  deciLM 7b
# 2       52927         6189  deciLM 7b
# 3       53555         3434  deciLM 7b
# 4       54407         4304  deciLM 7b
#
#                                    generated_summary   rouge_1   rouge_2  \
# 0       Person2 can't drive because of car problems.  0.105263  0.000000
# 1  Person2 is on a diet because of high cholesterol.  0.476190  0.300000
# 2      It was very cold last night and this morning.  0.216216  0.055556
# 3  Person 2 is driving too fast and Person 1 is t...  0.076923  0.000000
# 4  Zina's boyfriend is upset that she spends more...  0.222222  0.000000
#
#     rouge_l  bert_precision  bert_recall   bert_f1    meteor  \
# 0  0.105263        0.896172     0.835875  0.864974  0.075758
# 1  0.476190        0.915735     0.873921  0.894340  0.390959
# 2  0.162162        0.894284     0.826214  0.858903  0.124312
# 3  0.076923        0.924660     0.851687  0.886675  0.117778
# 4  0.222222        0.891302     0.873256  0.882187  0.133690
#
#    memory_summary_usage  time_summary_taken
# 0             91.131016            0.497037
# 1             88.231953            0.456419
# 2             88.415078            0.354811
# 3            112.787949            0.536884
# 4             84.814453            0.389443

# %%
falcon = get_model_summary_data('falcon 7b')
falcon.head()
# Out:
#    summary_id  dialogue_id   model_id  \
# 0       18034         5525  falcon 7b
# 1       19828        10619  falcon 7b
# 2       14177         1717  falcon 7b
# 3       15056         2587  falcon 7b
# 4       15146         2678  falcon 7b
#
#                                    generated_summary   rouge_1  rouge_2  \
# 0  Person1 offers assistance and various furnitur...  0.000000      0.0
# 1  Person1 and Person2 discuss services and wait ...  0.125000      0.0
# 2  Person1 and Person2 compliment each other on t...  0.000000      0.0
# 3  Person1 and Person2 are planning to attend eac...  0.181818      0.0
# 4  Tom and Person2 have agreed to cut the lung an...  0.214286      0.0
#
#     rouge_l  bert_precision  bert_recall   bert_f1    meteor  \
# 0  0.000000        0.876548     0.856002  0.866153  0.101351
# 1  0.125000        0.881582     0.840725  0.860669  0.124312
# 2  0.000000        0.871592     0.839751  0.855375  0.104167
# 3  0.181818        0.868931     0.877015  0.872954  0.221429
# 4  0.214286        0.853198     0.863161  0.858150  0.176056
#
#    memory_summary_usage  time_summary_taken
# 0             86.307773            0.443227
# 1             79.711406            0.742074
# 2             83.163301            0.420887
# 3             89.433145            0.393131
# 4             80.355000            0.402485

# %%
gemma = get_model_summary_data('gemma 7b')
gemma.head()
# Out:
#    summary_id  dialogue_id  model_id  \
# 0       44831         7228  gemma 7b
# 1       45975        12166  gemma 7b
# 2       45976        12169  gemma 7b
# 3       37754         3816  gemma 7b
# 4       37856          134  gemma 7b
#
#                                    generated_summary   rouge_1   rouge_2  \
# 0  The dialogue is about Person1 asking Person2 f...  0.048780  0.000000
# 1  The dialogue is about two people discussing th...  0.177778  0.000000
# 2  #Person1# inquires about the reason for #Perso...  0.139535  0.000000
# 3  The dialogue is about a person ordering a suit...  0.468085  0.259259
# 4  The dialogue is about making a reservation for...  0.133333  0.000000
#
#     rouge_l  bert_precision  bert_recall   bert_f1    meteor  \
# 0  0.048780        0.855926     0.848385  0.852139  0.073260
# 1  0.177778        0.856349     0.822137  0.838894  0.091864
# 2  0.139535        0.860959     0.858154  0.859554  0.181351
# 3  0.468085        0.893794     0.931543  0.912278  0.669124
# 4  0.133333        0.853920     0.848065  0.850983  0.171674
#
#    memory_summary_usage  time_summary_taken
# 0            869.443672            0.845171
# 1            825.625586            0.703312
# 2            825.625586            0.703312
# 3            750.495742            0.633181
# 4            792.906582            0.680239

# %%
llama = get_model_summary_data('llama 3 8b')
llama.head()
# Out:
#    summary_id  dialogue_id    model_id  \
# 0       29845         4605  llama 3 8b
# 1       25327         3816  llama 3 8b
# 2       25328            3  llama 3 8b
# 3       25329            4  llama 3 8b
# 4       25330            5  llama 3 8b
#
#                                    generated_summary   rouge_1   rouge_2  \
# 0  Person 2 had a punishment in college many year...  0.133333  0.066667
# 1  Person 1 is a tailor who is asked by Person 2 ...  0.370370  0.126984
# 2  Person1 asks Person2 if they saw a set of keys...  0.408163  0.111111
# 3  Person1 is upset because Person2 didn't tell t...  0.264151  0.030303
# 4  Malik approaches Wen and Nikki at a party and ...  0.196078  0.057143
#
#     rouge_l  bert_precision  bert_recall   bert_f1    meteor  \
# 0  0.133333        0.869942     0.839889  0.854651  0.235849
# 1  0.370370        0.873162     0.919966  0.895953  0.554318
# 2  0.285714        0.880703     0.876892  0.878794  0.409627
# 3  0.226415        0.877741     0.872372  0.875048  0.257764
# 4  0.196078        0.870300     0.885064  0.877620  0.213675
#
#    memory_summary_usage  time_summary_taken
# 0            290.540957            0.851161
# 1            261.101680            0.830643
# 2            261.101680            0.830643
# 3            261.101680            0.830643
# 4            261.101680            0.830643

# %%
mistral = get_model_summary_data('mistral 7b')
mistral.head()
# Out:
#    summary_id  dialogue_id    model_id  \
# 0           1            1  mistral 7b
# 1           2            2  mistral 7b
# 2           3            3  mistral 7b
# 3           4            4  mistral 7b
# 4           5            5  mistral 7b
#
#                                    generated_summary   rouge_1   rouge_2  \
# 0  Doctor Hawkins greets Mr. Smith and asks why h...  0.351351  0.159091
# 1  Person1 greets Person2 and checks Ricky's vacc...  0.250000  0.000000
# 2  Person1 lost a set of five keys with a small f...  0.367347  0.074074
# 3  Person1 was upset that Person2 had a girlfrien...  0.233333  0.105263
# 4  Malik approaches Wen and Nikki at the dance fl...  0.392857  0.120482
#
#     rouge_l  bert_precision  bert_recall   bert_f1    meteor  \
# 0  0.324324        0.888796     0.906006  0.897319  0.505513
# 1  0.218750        0.836484     0.907462  0.870528  0.335816
# 2  0.285714        0.880228     0.880754  0.880491  0.363356
# 3  0.166667        0.868038     0.871339  0.869685  0.304503
# 4  0.392857        0.869606     0.924768  0.896339  0.529660
#
#   memory_summary_usage time_summary_taken
# 0                 None               None
# 1                 None               None
# 2                 None               None
# 3                 None               None
# 4                 None               None

# %%
orca = get_model_summary_data('orca2 7b')
orca.head()
# Out:
#    summary_id  dialogue_id  model_id  \
# 0       63853         4917  orca2 7b
# 1       63226         4285  orca2 7b
# 2       63589          978  orca2 7b
# 3       66947         8281  orca2 7b
# 4       62608         3816  orca2 7b
#
#                                    generated_summary   rouge_1   rouge_2  \
# 0  If your car breaks down, call the provided num...  0.272727  0.095238
# 1  A customer orders a beer and accidentally spil...  0.296296  0.148148
# 2  Henry asks Person2 for a loan, but Person2 dec...  0.428571  0.071429
# 3  The weather report said it will be cloudy, win...  0.250000  0.173913
# 4  Person2 wants a suit made to measure in black ...  0.611111  0.400000
#
#     rouge_l  bert_precision  bert_recall   bert_f1    meteor  \
# 0  0.181818        0.900593     0.853863  0.876606  0.307898
# 1  0.296296        0.893684     0.843980  0.868121  0.245051
# 2  0.285714        0.913308     0.903696  0.908477  0.364884
# 3  0.250000        0.871713     0.844208  0.857740  0.316340
# 4  0.611111        0.933762     0.934884  0.934322  0.689691
#
#    memory_summary_usage  time_summary_taken
# 0            847.760527            0.494939
# 1            757.757871            0.452261
# 2            841.760195            0.497363
# 3            713.756992            0.418482
# 4            775.550723            0.513281

# %%
zephyr = get_model_summary_data('zephyr 7b beta')
zephyr.head()
# Out:
#    summary_id  dialogue_id        model_id  \
# 0       82221         7337  zephyr 7b beta
# 1       75108         1984  zephyr 7b beta
# 2       75035         3816  zephyr 7b beta
# 3       75036            3  zephyr 7b beta
# 4       75037            4  zephyr 7b beta
#
#                                    generated_summary   rouge_1   rouge_2  \
# 0  A person inquires about vacancy, is informed o...  0.214286  0.153846
# 1  Two people introduce themselves and confirm ea...  0.181818  0.000000
# 2  A customer requests a custom-made suit in blac...  0.421053  0.162162
# 3  Two people are searching for a set of keys tha...  0.400000  0.277778
# 4  The conversation revolves around a person (#Pe...  0.153846  0.000000
#
#     rouge_l  bert_precision  bert_recall   bert_f1    meteor  \
# 0  0.214286        0.854803     0.849707  0.852247  0.337879
# 1  0.181818        0.897488     0.891543  0.894505  0.216182
# 2  0.421053        0.915753     0.918569  0.917159  0.548682
# 3  0.400000        0.902532     0.872277  0.887147  0.369866
# 4  0.153846        0.868802     0.893410  0.880934  0.259740
#
#    memory_summary_usage  time_summary_taken
# 0            230.882441            0.647024
# 1            233.539883            0.613193
# 2            213.580879            0.534402
# 3            213.580879            0.534402
# 4            213.580879            0.534402

# %% [markdown]
# Plot 1: Bertscore Density Graph

# %%
bert_df = pd.DataFrame({
    'DeciLM': deci['bert_f1'],
    'Falcon': falcon['bert_f1'],
    'Gemma': gemma['bert_f1'],
    'Llama 3': llama['bert_f1'],
    'Mistral': mistral['bert_f1'],
    'Orca 2': orca['bert_f1'],
    'Zephyr': zephyr['bert_f1']
})

bert_df.head()
# Out:
#      DeciLM    Falcon     Gemma   Llama 3   Mistral    Orca 2    Zephyr
# 0  0.864974  0.866153  0.852139  0.854651  0.897319  0.876606  0.852247
# 1  0.894340  0.860669  0.838894  0.895953  0.870528  0.868121  0.894505
# 2  0.858903  0.855375  0.859554  0.878794  0.880491  0.908477  0.917159
# 3  0.886675  0.872954  0.912278  0.875048  0.869685  0.857740  0.887147
# 4  0.882187  0.858150  0.850983  0.877620  0.896339  0.934322  0.880934

# %%
melted_bert_df = pd.melt(bert_df, var_name="LLM Model", value_name="Bertscore")
melted_bert_df.head()
# Out:
#   LLM Model  Bertscore
# 0    DeciLM   0.864974
# 1    DeciLM   0.894340
# 2    DeciLM   0.858903
# 3    DeciLM   0.886675
# 4    DeciLM   0.882187

# %%
plt.figure(figsize=(12, 8))
sns.kdeplot(data=melted_bert_df, x='Bertscore', hue='LLM Model', fill=True, common_norm=False, palette="magma")

# Add title and labels
plt.title('Density Plot of Memory Performance Across Models')
plt.xlabel('Bertscore')
plt.ylabel('Density')

# Show the plot
plt.show()

# %% [markdown]
# Plot 2: Boxplot of Bertscore

# %%
plt.figure(figsize=(12, 8))
sns.set_theme(style="whitegrid")
sns.boxplot(x = "LLM Model", y = "Bertscore", data = melted_bert_df, palette='magma', hue="LLM Model")
plt.title('Comparison of Bertscore Across Models', fontsize=16, pad=14)
plt.xlabel('LLM Model')
plt.ylabel('Bertscore')
plt.show()

# %% [markdown]
# Plot 3: Grid of density plots of each model

# %%
sub_bert_df1 = pd.DataFrame({
    'DeciLM': deci['bert_f1'],
    'Falcon': falcon['bert_f1'],
    'Gemma': gemma['bert_f1'],
    'Llama 3': llama['bert_f1'],
})
sub_bert_df1.head()
# Out:
#      DeciLM    Falcon     Gemma   Llama 3
# 0  0.864974  0.866153  0.852139  0.854651
# 1  0.894340  0.860669  0.838894  0.895953
# 2  0.858903  0.855375  0.859554  0.878794
# 3  0.886675  0.872954  0.912278  0.875048
# 4  0.882187  0.858150  0.850983  0.877620

# %%
sub_bert_df2 = pd.DataFrame({
    'Mistral': mistral['bert_f1'],
    'Orca 2': orca['bert_f1'],
    'Zephyr': zephyr['bert_f1']
})
sub_bert_df2.head()
# Out:
#     Mistral    Orca 2    Zephyr
# 0  0.897319  0.876606  0.852247
# 1  0.870528  0.868121  0.894505
# 2  0.880491  0.908477  0.917159
# 3  0.869685  0.857740  0.887147
# 4  0.896339  0.934322  0.880934

# %%
sub_melted_bert_df1 = pd.melt(sub_bert_df1, var_name="LLM Model", value_name="Bertscore")
sub_melted_bert_df1.head()
# Out:
#   LLM Model  Bertscore
# 0    DeciLM   0.864974
# 1    DeciLM   0.894340
# 2    DeciLM   0.858903
# 3    DeciLM   0.886675
# 4    DeciLM   0.882187

# %%
sub_melted_bert_df2 = pd.melt(sub_bert_df2, var_name="LLM Model", value_name="Bertscore")
sub_melted_bert_df2.head()
# Out:
#   LLM Model  Bertscore
# 0   Mistral   0.897319
# 1   Mistral   0.870528
# 2   Mistral   0.880491
# 3   Mistral   0.869685
# 4   Mistral   0.896339

# %%
# Initialize the FacetGrid object
g = sns.FacetGrid(melted_bert_df, col="LLM Model", col_wrap=7, height=4, hue="LLM Model",  palette="magma")

# Map the seaborn kdeplot function to the FacetGrid
g.map(sns.kdeplot, "Bertscore", fill=True)

# Add titles to the plots
g.set_titles(col_template="{col_name}")

# Show the plot
plt.show()
